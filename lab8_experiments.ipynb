# %% [markdown]
# 1 архитектура) Предложенная архитектура lr=0.001 Adam 5 эпох

# %%
# Эпоха 1/5: train_loss=1.3784, train_acc=0.5020, test_loss=1.1075, test_acc=0.6110
# Эпоха 2/5: train_loss=0.9504, train_acc=0.6655, test_loss=0.8998, test_acc=0.6889
# Эпоха 3/5: train_loss=0.7832, train_acc=0.7257, test_loss=0.8119, test_acc=0.7220
# Эпоха 4/5: train_loss=0.6565, train_acc=0.7701, test_loss=0.7766, test_acc=0.7368
# Эпоха 5/5: train_loss=0.5531, train_acc=0.8055, test_loss=0.7391, test_acc=0.7558

# %% [markdown]
# 1 архитектура) Предложенная архитектура lr=0.001 Adam 30 эпох

# %%
# Эпоха 1/30: train_loss=1.4162, train_acc=0.4907, test_loss=1.1169, test_acc=0.5973
# Эпоха 2/30: train_loss=0.9746, train_acc=0.6558, test_loss=0.9393, test_acc=0.6740
# Эпоха 3/30: train_loss=0.7880, train_acc=0.7233, test_loss=0.8577, test_acc=0.6993
# Эпоха 4/30: train_loss=0.6711, train_acc=0.7649, test_loss=0.8000, test_acc=0.7333
# Эпоха 5/30: train_loss=0.5771, train_acc=0.7982, test_loss=0.7329, test_acc=0.7542
# Эпоха 6/30: train_loss=0.4840, train_acc=0.8326, test_loss=0.7036, test_acc=0.7595
# Эпоха 7/30: train_loss=0.4055, train_acc=0.8584, test_loss=0.7664, test_acc=0.7616
# Эпоха 8/30: train_loss=0.3386, train_acc=0.8803, test_loss=0.7623, test_acc=0.7649
# Эпоха 9/30: train_loss=0.2682, train_acc=0.9056, test_loss=0.8050, test_acc=0.7657
# Эпоха 10/30: train_loss=0.2085, train_acc=0.9269, test_loss=0.9087, test_acc=0.7632
# Эпоха 11/30: train_loss=0.1628, train_acc=0.9432, test_loss=0.9802, test_acc=0.7631
# Эпоха 12/30: train_loss=0.1357, train_acc=0.9522, test_loss=1.0332, test_acc=0.7659
# Эпоха 13/30: train_loss=0.1075, train_acc=0.9618, test_loss=1.1647, test_acc=0.7541
# Эпоха 14/30: train_loss=0.0897, train_acc=0.9682, test_loss=1.2189, test_acc=0.7622
# Эпоха 15/30: train_loss=0.0849, train_acc=0.9705, test_loss=1.2909, test_acc=0.7583
# Эпоха 16/30: train_loss=0.0794, train_acc=0.9724, test_loss=1.3975, test_acc=0.7515
# Эпоха 17/30: train_loss=0.0679, train_acc=0.9769, test_loss=1.4344, test_acc=0.7577
# Эпоха 18/30: train_loss=0.0755, train_acc=0.9730, test_loss=1.4184, test_acc=0.7538
# Эпоха 19/30: train_loss=0.0680, train_acc=0.9766, test_loss=1.5262, test_acc=0.7584
# Эпоха 20/30: train_loss=0.0587, train_acc=0.9794, test_loss=1.6300, test_acc=0.7519
# Эпоха 21/30: train_loss=0.0663, train_acc=0.9773, test_loss=1.5924, test_acc=0.7573
# Эпоха 22/30: train_loss=0.0610, train_acc=0.9788, test_loss=1.6851, test_acc=0.7497
# Эпоха 23/30: train_loss=0.0519, train_acc=0.9815, test_loss=1.7912, test_acc=0.7404
# Эпоха 24/30: train_loss=0.0625, train_acc=0.9782, test_loss=1.8037, test_acc=0.7544
# Эпоха 25/30: train_loss=0.0443, train_acc=0.9843, test_loss=1.8631, test_acc=0.7571
# Эпоха 26/30: train_loss=0.0426, train_acc=0.9857, test_loss=1.8009, test_acc=0.7538
# Эпоха 27/30: train_loss=0.0434, train_acc=0.9857, test_loss=1.8740, test_acc=0.7530
# Эпоха 28/30: train_loss=0.0550, train_acc=0.9826, test_loss=1.9628, test_acc=0.7461
# Эпоха 29/30: train_loss=0.0573, train_acc=0.9813, test_loss=1.7968, test_acc=0.7576
# Эпоха 30/30: train_loss=0.0460, train_acc=0.9844, test_loss=1.9637, test_acc=0.7512

# %% [markdown]
# 2 архитектура) К старой архитектуре добавлены BatchNorm и Dropout
# В оптимизаторе оставила Adam с lr=1e-3
# На 5 эпох

# %%
# Эпоха 1/5: train_loss=0.1239, train_acc=0.9578, test_loss=1.0298, test_acc=0.7587
# Эпоха 2/5: train_loss=0.0843, train_acc=0.9711, test_loss=1.1571, test_acc=0.7548
# Эпоха 3/5: train_loss=0.0807, train_acc=0.9723, test_loss=1.2119, test_acc=0.7580
# Эпоха 4/5: train_loss=0.0823, train_acc=0.9711, test_loss=1.2730, test_acc=0.7601
# Эпоха 5/5: train_loss=0.0687, train_acc=0.9763, test_loss=1.3839, test_acc=0.7529

# %% [markdown]
# 2 архитектура) К старой архитектуре добавлены BatchNorm и Dropout
# В оптимизаторе оставила Adam с lr=1e-3
# На 20 эпох

# %%
# Эпоха 1/20: train_loss=0.0715, train_acc=0.9755, test_loss=1.4472, test_acc=0.7478
# Эпоха 2/20: train_loss=0.0673, train_acc=0.9769, test_loss=1.4793, test_acc=0.7552
# Эпоха 3/20: train_loss=0.0585, train_acc=0.9793, test_loss=1.6029, test_acc=0.7505
# Эпоха 4/20: train_loss=0.0518, train_acc=0.9820, test_loss=1.6255, test_acc=0.7640
# Эпоха 5/20: train_loss=0.0558, train_acc=0.9813, test_loss=1.6733, test_acc=0.7588
# Эпоха 6/20: train_loss=0.0532, train_acc=0.9817, test_loss=1.7466, test_acc=0.7569
# Эпоха 7/20: train_loss=0.0499, train_acc=0.9829, test_loss=1.7599, test_acc=0.7541
# Эпоха 8/20: train_loss=0.0654, train_acc=0.9783, test_loss=1.6436, test_acc=0.7574
# Эпоха 9/20: train_loss=0.0522, train_acc=0.9832, test_loss=1.7731, test_acc=0.7593
# Эпоха 10/20: train_loss=0.0535, train_acc=0.9822, test_loss=1.7540, test_acc=0.7564
# Эпоха 11/20: train_loss=0.0425, train_acc=0.9860, test_loss=1.9013, test_acc=0.7610
# Эпоха 12/20: train_loss=0.0546, train_acc=0.9820, test_loss=1.8383, test_acc=0.7543
# Эпоха 13/20: train_loss=0.0503, train_acc=0.9835, test_loss=1.9686, test_acc=0.7529
# Эпоха 14/20: train_loss=0.0495, train_acc=0.9841, test_loss=2.0191, test_acc=0.7549
# Эпоха 15/20: train_loss=0.0441, train_acc=0.9854, test_loss=1.9734, test_acc=0.7527
# Эпоха 16/20: train_loss=0.0441, train_acc=0.9863, test_loss=2.0941, test_acc=0.7518
# Эпоха 17/20: train_loss=0.0486, train_acc=0.9843, test_loss=2.0781, test_acc=0.7544
# Эпоха 18/20: train_loss=0.0390, train_acc=0.9871, test_loss=2.1245, test_acc=0.7599
# Эпоха 19/20: train_loss=0.0331, train_acc=0.9888, test_loss=2.1849, test_acc=0.7508
# Эпоха 20/20: train_loss=0.0489, train_acc=0.9850, test_loss=2.2331, test_acc=0.7474

# %% [markdown]
# 3 архитектура в файле, SGD + mometum=0.9, lr=0.01 wd=1e-4
# 5 эпох

# %%
# Эпоха 1/5: train_loss=1.3239, train_acc=0.5193, test_loss=1.0354, test_acc=0.6303
# Эпоха 2/5: train_loss=0.9483, train_acc=0.6620, test_loss=0.8843, test_acc=0.6873
# Эпоха 3/5: train_loss=0.8092, train_acc=0.7151, test_loss=0.8694, test_acc=0.6928
# Эпоха 4/5: train_loss=0.7207, train_acc=0.7452, test_loss=0.8965, test_acc=0.6935
# Эпоха 5/5: train_loss=0.6453, train_acc=0.7733, test_loss=0.6914, test_acc=0.7615

# %% [markdown]
# 3 архитектура в файле, SGD + mometum=0.9, lr=0.01 wd=1e-4
# 30 эпох

# %%
# Эпоха 1/30: train_loss=0.5845, train_acc=0.7937, test_loss=0.7109, test_acc=0.7543
# Эпоха 2/30: train_loss=0.5276, train_acc=0.8140, test_loss=0.7141, test_acc=0.7611
# Эпоха 3/30: train_loss=0.4819, train_acc=0.8302, test_loss=0.6858, test_acc=0.7651
# Эпоха 4/30: train_loss=0.4305, train_acc=0.8472, test_loss=0.6785, test_acc=0.7767
# Эпоха 5/30: train_loss=0.3879, train_acc=0.8635, test_loss=0.6545, test_acc=0.7880
# Эпоха 6/30: train_loss=0.3549, train_acc=0.8733, test_loss=0.6480, test_acc=0.7943
# Эпоха 7/30: train_loss=0.3222, train_acc=0.8861, test_loss=0.6746, test_acc=0.7855
# Эпоха 8/30: train_loss=0.2890, train_acc=0.8962, test_loss=0.6575, test_acc=0.7882
# Эпоха 9/30: train_loss=0.2559, train_acc=0.9099, test_loss=0.6774, test_acc=0.7854
# Эпоха 10/30: train_loss=0.2304, train_acc=0.9192, test_loss=0.6684, test_acc=0.8021
# Эпоха 11/30: train_loss=0.2023, train_acc=0.9295, test_loss=0.6989, test_acc=0.7939
# Эпоха 12/30: train_loss=0.1830, train_acc=0.9355, test_loss=0.7200, test_acc=0.7947
# Эпоха 13/30: train_loss=0.1658, train_acc=0.9431, test_loss=0.7351, test_acc=0.7906
# Эпоха 14/30: train_loss=0.1546, train_acc=0.9467, test_loss=0.7163, test_acc=0.8020
# Эпоха 15/30: train_loss=0.1351, train_acc=0.9520, test_loss=0.7906, test_acc=0.7967
# Эпоха 16/30: train_loss=0.1244, train_acc=0.9566, test_loss=0.7775, test_acc=0.7977
# Эпоха 17/30: train_loss=0.1090, train_acc=0.9625, test_loss=0.8241, test_acc=0.7860
# Эпоха 18/30: train_loss=0.1050, train_acc=0.9650, test_loss=0.8161, test_acc=0.7942
# Эпоха 19/30: train_loss=0.0902, train_acc=0.9700, test_loss=0.7996, test_acc=0.8034
# Эпоха 20/30: train_loss=0.0806, train_acc=0.9728, test_loss=0.8619, test_acc=0.7986
# Эпоха 21/30: train_loss=0.0820, train_acc=0.9727, test_loss=0.7983, test_acc=0.8044
# Эпоха 22/30: train_loss=0.0681, train_acc=0.9775, test_loss=0.8932, test_acc=0.7974
# Эпоха 23/30: train_loss=0.0692, train_acc=0.9766, test_loss=0.8443, test_acc=0.8083
# Эпоха 24/30: train_loss=0.0633, train_acc=0.9798, test_loss=0.9104, test_acc=0.8022
# Эпоха 25/30: train_loss=0.0595, train_acc=0.9799, test_loss=0.9177, test_acc=0.8037
# Эпоха 26/30: train_loss=0.0519, train_acc=0.9837, test_loss=0.9544, test_acc=0.7990
# Эпоха 27/30: train_loss=0.0512, train_acc=0.9829, test_loss=0.9550, test_acc=0.7974
# Эпоха 28/30: train_loss=0.0510, train_acc=0.9836, test_loss=0.9348, test_acc=0.8060
# Эпоха 29/30: train_loss=0.0457, train_acc=0.9854, test_loss=0.9609, test_acc=0.7971
# Эпоха 30/30: train_loss=0.0452, train_acc=0.9853, test_loss=0.9340, test_acc=0.8045

# %%
# latent_dim = 16, batch_size=128, num_epochs = 15
# Эпоха 1/15: train_loss=0.0528, test_loss=0.0312
# Эпоха 2/15: train_loss=0.0271, test_loss=0.0233
# Эпоха 3/15: train_loss=0.0213, test_loss=0.0191
# Эпоха 4/15: train_loss=0.0182, test_loss=0.0168
# Эпоха 5/15: train_loss=0.0164, test_loss=0.0154
# Эпоха 6/15: train_loss=0.0153, test_loss=0.0144
# Эпоха 7/15: train_loss=0.0143, test_loss=0.0137
# Эпоха 8/15: train_loss=0.0136, test_loss=0.0131
# Эпоха 9/15: train_loss=0.0131, test_loss=0.0127
# Эпоха 10/15: train_loss=0.0127, test_loss=0.0124
# Эпоха 11/15: train_loss=0.0124, test_loss=0.0121
# Эпоха 12/15: train_loss=0.0120, test_loss=0.0118
# Эпоха 13/15: train_loss=0.0117, test_loss=0.0115
# Эпоха 14/15: train_loss=0.0114, test_loss=0.0112
# Эпоха 15/15: train_loss=0.0112, test_loss=0.0110

# %%
# latent_dim = 16, batch_size=128, num_epochs = 25
# Эпоха 1/25: train_loss=0.0541, test_loss=0.0325
# Эпоха 2/25: train_loss=0.0287, test_loss=0.0255
# Эпоха 3/25: train_loss=0.0244, test_loss=0.0228
# Эпоха 4/25: train_loss=0.0216, test_loss=0.0202
# Эпоха 5/25: train_loss=0.0196, test_loss=0.0184
# Эпоха 6/25: train_loss=0.0179, test_loss=0.0167
# Эпоха 7/25: train_loss=0.0164, test_loss=0.0156
# Эпоха 8/25: train_loss=0.0152, test_loss=0.0145
# Эпоха 9/25: train_loss=0.0144, test_loss=0.0139
# Эпоха 10/25: train_loss=0.0137, test_loss=0.0132
# Эпоха 11/25: train_loss=0.0131, test_loss=0.0126
# Эпоха 12/25: train_loss=0.0125, test_loss=0.0121
# Эпоха 13/25: train_loss=0.0122, test_loss=0.0120
# Эпоха 14/25: train_loss=0.0118, test_loss=0.0117
# Эпоха 15/25: train_loss=0.0116, test_loss=0.0114
# Эпоха 16/25: train_loss=0.0113, test_loss=0.0112
# Эпоха 17/25: train_loss=0.0111, test_loss=0.0110
# Эпоха 18/25: train_loss=0.0109, test_loss=0.0109
# Эпоха 19/25: train_loss=0.0108, test_loss=0.0108
# Эпоха 20/25: train_loss=0.0107, test_loss=0.0106
# Эпоха 21/25: train_loss=0.0105, test_loss=0.0105
# Эпоха 22/25: train_loss=0.0104, test_loss=0.0104
# Эпоха 23/25: train_loss=0.0103, test_loss=0.0104
# Эпоха 24/25: train_loss=0.0102, test_loss=0.0103
# Эпоха 25/25: train_loss=0.0101, test_loss=0.0103

# %%
# latent_dim = 2, batch_size=128, num_epochs = 15
# Эпоха 1/15: train_loss=0.0489, test_loss=0.0460
# Эпоха 2/15: train_loss=0.0449, test_loss=0.0438
# Эпоха 3/15: train_loss=0.0430, test_loss=0.0422
# Эпоха 4/15: train_loss=0.0418, test_loss=0.0414
# Эпоха 5/15: train_loss=0.0409, test_loss=0.0406
# Эпоха 6/15: train_loss=0.0403, test_loss=0.0403
# Эпоха 7/15: train_loss=0.0398, test_loss=0.0397
# Эпоха 8/15: train_loss=0.0394, test_loss=0.0393
# Эпоха 9/15: train_loss=0.0390, test_loss=0.0391
# Эпоха 10/15: train_loss=0.0387, test_loss=0.0388
# Эпоха 11/15: train_loss=0.0384, test_loss=0.0386
# Эпоха 12/15: train_loss=0.0381, test_loss=0.0385
# Эпоха 13/15: train_loss=0.0379, test_loss=0.0383
# Эпоха 14/15: train_loss=0.0377, test_loss=0.0381
# Эпоха 15/15: train_loss=0.0375, test_loss=0.0378

# %%
# latent_dim = 128, batch_size=128, num_epochs = 15
# Эпоха 1/15: train_loss=0.0521, test_loss=0.0296
# Эпоха 2/15: train_loss=0.0251, test_loss=0.0213
# Эпоха 3/15: train_loss=0.0196, test_loss=0.0174
# Эпоха 4/15: train_loss=0.0165, test_loss=0.0152
# Эпоха 5/15: train_loss=0.0146, test_loss=0.0135
# Эпоха 6/15: train_loss=0.0132, test_loss=0.0122
# Эпоха 7/15: train_loss=0.0121, test_loss=0.0113
# Эпоха 8/15: train_loss=0.0112, test_loss=0.0108
# Эпоха 9/15: train_loss=0.0104, test_loss=0.0099
# Эпоха 10/15: train_loss=0.0098, test_loss=0.0093
# Эпоха 11/15: train_loss=0.0093, test_loss=0.0089
# Эпоха 12/15: train_loss=0.0089, test_loss=0.0086
# Эпоха 13/15: train_loss=0.0086, test_loss=0.0084
# Эпоха 14/15: train_loss=0.0082, test_loss=0.0081
# Эпоха 15/15: train_loss=0.0080, test_loss=0.0078

# %%
# latent_dim = 16, batch_size=128, num_epochs = 15, +1 слой
# Эпоха 1/15: train_loss=0.0607, test_loss=0.0394
# Эпоха 2/15: train_loss=0.0330, test_loss=0.0290
# Эпоха 3/15: train_loss=0.0275, test_loss=0.0259
# Эпоха 4/15: train_loss=0.0249, test_loss=0.0232
# Эпоха 5/15: train_loss=0.0227, test_loss=0.0216
# Эпоха 6/15: train_loss=0.0208, test_loss=0.0196
# Эпоха 7/15: train_loss=0.0191, test_loss=0.0182
# Эпоха 8/15: train_loss=0.0179, test_loss=0.0170
# Эпоха 9/15: train_loss=0.0165, test_loss=0.0157
# Эпоха 10/15: train_loss=0.0155, test_loss=0.0150
# Эпоха 11/15: train_loss=0.0149, test_loss=0.0146
# Эпоха 12/15: train_loss=0.0143, test_loss=0.0140
# Эпоха 13/15: train_loss=0.0138, test_loss=0.0135
# Эпоха 14/15: train_loss=0.0133, test_loss=0.0131
# Эпоха 15/15: train_loss=0.0128, test_loss=0.0127

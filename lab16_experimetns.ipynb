# %%
# patch_size = 4
# Эпоха 1/5 | Train Loss: 1.7802, Acc: 0.3349 | Test Loss: 1.5375, Acc: 0.4264
# Эпоха 2/5 | Train Loss: 1.4718, Acc: 0.4572 | Test Loss: 1.3337, Acc: 0.5116
# Эпоха 3/5 | Train Loss: 1.3157, Acc: 0.5197 | Test Loss: 1.2632, Acc: 0.5370
# Эпоха 4/5 | Train Loss: 1.2221, Acc: 0.5580 | Test Loss: 1.1821, Acc: 0.5748
# Эпоха 5/5 | Train Loss: 1.1521, Acc: 0.5819 | Test Loss: 1.1774, Acc: 0.5714

# %%
# patch_size = 16
# Эпоха 1/5 | Train Loss: 1.8430, Acc: 0.3307 | Test Loss: 1.6845, Acc: 0.3916
# Эпоха 2/5 | Train Loss: 1.6738, Acc: 0.3951 | Test Loss: 1.5942, Acc: 0.4270
# Эпоха 3/5 | Train Loss: 1.5975, Acc: 0.4253 | Test Loss: 1.5633, Acc: 0.4444
# Эпоха 4/5 | Train Loss: 1.5323, Acc: 0.4478 | Test Loss: 1.4731, Acc: 0.4703
# Эпоха 5/5 | Train Loss: 1.4802, Acc: 0.4657 | Test Loss: 1.4501, Acc: 0.4788

# %%
# patch_size = 4 embed_dim = 128 depth = 4 heads = 4
# Эпоха 1/5 | Train Loss: 1.6581, Acc: 0.3815 | Test Loss: 1.3469, Acc: 0.5095
# Эпоха 2/5 | Train Loss: 1.2622, Acc: 0.5406 | Test Loss: 1.1729, Acc: 0.5774
# Эпоха 3/5 | Train Loss: 1.1010, Acc: 0.6034 | Test Loss: 1.0456, Acc: 0.6210
# Эпоха 4/5 | Train Loss: 1.0063, Acc: 0.6398 | Test Loss: 1.0655, Acc: 0.6240
# Эпоха 5/5 | Train Loss: 0.9374, Acc: 0.6633 | Test Loss: 0.9335, Acc: 0.6694

# %%
# patch_size = 4 embed_dim = 128 depth = 6 heads = 4
# Эпоха 1/5 | Train Loss: 1.6995, Acc: 0.3628 | Test Loss: 1.4476, Acc: 0.4711
# Эпоха 2/5 | Train Loss: 1.2917, Acc: 0.5281 | Test Loss: 1.1731, Acc: 0.5737
# Эпоха 3/5 | Train Loss: 1.1202, Acc: 0.5956 | Test Loss: 1.0617, Acc: 0.6210
# Эпоха 4/5 | Train Loss: 1.0113, Acc: 0.6386 | Test Loss: 1.0379, Acc: 0.6320
# Эпоха 5/5 | Train Loss: 0.9300, Acc: 0.6679 | Test Loss: 0.9324, Acc: 0.6683

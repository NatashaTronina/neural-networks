# %%
# предложенная архитектура, batch_size=64
# Эпоха 1/30 | loss_G=1.6978, loss_D=0.9628

# Эпоха 2/30 | loss_G=2.9152, loss_D=0.6593
# Эпоха 3/30 | loss_G=3.3414, loss_D=0.5850
# Эпоха 4/30 | loss_G=3.5814, loss_D=0.5954
# Эпоха 5/30 | loss_G=3.4919, loss_D=0.6096

# Эпоха 6/30 | loss_G=3.8976, loss_D=0.5493
# Эпоха 7/30 | loss_G=3.6578, loss_D=0.5214
# Эпоха 8/30 | loss_G=4.1530, loss_D=0.4598
# Эпоха 9/30 | loss_G=3.8916, loss_D=0.5022
# Эпоха 10/30 | loss_G=4.2765, loss_D=0.4420

# Эпоха 11/30 | loss_G=5.3966, loss_D=0.1321
# Эпоха 12/30 | loss_G=5.0026, loss_D=0.1619
# Эпоха 13/30 | loss_G=6.9822, loss_D=0.0079
# Эпоха 14/30 | loss_G=8.9101, loss_D=0.0005
# Эпоха 15/30 | loss_G=10.1863, loss_D=0.0002

# Эпоха 16/30 | loss_G=8.0620, loss_D=0.0664
# Эпоха 17/30 | loss_G=8.6249, loss_D=0.0007
# Эпоха 18/30 | loss_G=8.9955, loss_D=0.0145
# Эпоха 19/30 | loss_G=9.7957, loss_D=0.0001
# Эпоха 20/30 | loss_G=9.9090, loss_D=0.0252

# Эпоха 21/30 | loss_G=11.5136, loss_D=0.0000
# Эпоха 22/30 | loss_G=12.2678, loss_D=0.0000
# Эпоха 23/30 | loss_G=12.7888, loss_D=0.0000
# Эпоха 24/30 | loss_G=10.3721, loss_D=0.0359
# Эпоха 25/30 | loss_G=8.3688, loss_D=0.0209

# Эпоха 26/30 | loss_G=10.0561, loss_D=0.0001
# Эпоха 27/30 | loss_G=11.2785, loss_D=0.0000
# Эпоха 28/30 | loss_G=11.2367, loss_D=0.0026
# Эпоха 29/30 | loss_G=12.7280, loss_D=0.0000
# Эпоха 30/30 | loss_G=13.6618, loss_D=0.0000

# %%
# предложенная архитектура, batch_size=64 + BatchNorm в Generator - норм картинки
# Эпоха 1/15 | loss_G=0.8369, loss_D=1.3143

# Эпоха 2/15 | loss_G=0.8297, loss_D=1.3170
# Эпоха 3/15 | loss_G=0.8282, loss_D=1.3174
# Эпоха 4/15 | loss_G=0.8311, loss_D=1.3163
# Эпоха 5/15 | loss_G=0.8284, loss_D=1.3162

# Эпоха 6/15 | loss_G=0.8257, loss_D=1.3200
# Эпоха 7/15 | loss_G=0.8220, loss_D=1.3201
# Эпоха 8/15 | loss_G=0.8232, loss_D=1.3218
# Эпоха 9/15 | loss_G=0.8231, loss_D=1.3206
# Эпоха 10/15 | loss_G=0.8199, loss_D=1.3194

# Эпоха 11/15 | loss_G=0.8230, loss_D=1.3195
# Эпоха 12/15 | loss_G=0.8245, loss_D=1.3187
# Эпоха 13/15 | loss_G=0.8207, loss_D=1.3193
# Эпоха 14/15 | loss_G=0.8209, loss_D=1.3199
# Эпоха 15/15 | loss_G=0.8219, loss_D=1.3185

# %%
# предложенная архитектура, batch_size=64 + BatchNorm в Generator + Dropout=0.3 в Generator + функция потерь - BCEWithLogitsLoss() -норм картинки
# Эпоха 1/15 | loss_G=1.1598, loss_D=1.1501

# Эпоха 2/15 | loss_G=1.3393, loss_D=1.0887
# Эпоха 3/15 | loss_G=1.2374, loss_D=1.1258
# Эпоха 4/15 | loss_G=1.1400, loss_D=1.1442
# Эпоха 5/15 | loss_G=1.0273, loss_D=1.2089

# Эпоха 6/15 | loss_G=0.9174, loss_D=1.2583
# Эпоха 7/15 | loss_G=0.8846, loss_D=1.2846
# Эпоха 8/15 | loss_G=0.8481, loss_D=1.3035
# Эпоха 9/15 | loss_G=0.8243, loss_D=1.3199
# Эпоха 10/15 | loss_G=0.8100, loss_D=1.3283

# Эпоха 11/15 | loss_G=0.7908, loss_D=1.3395
# Эпоха 12/15 | loss_G=0.7826, loss_D=1.3459
# Эпоха 13/15 | loss_G=0.7718, loss_D=1.3522
# Эпоха 14/15 | loss_G=0.7611, loss_D=1.3575
# Эпоха 15/15 | loss_G=0.7569, loss_D=1.3615

# %%
# предложенная архитектура, batch_size=64 + BatchNorm в Generator + z_dim = 150 - шумные картинки
# Эпоха 1/15 | loss_G=1.2463, loss_D=1.1116

# Эпоха 2/15 | loss_G=1.4625, loss_D=1.0671
# Эпоха 3/15 | loss_G=1.3453, loss_D=1.1011
# Эпоха 4/15 | loss_G=1.2496, loss_D=1.1421
# Эпоха 5/15 | loss_G=1.1491, loss_D=1.1593

# Эпоха 6/15 | loss_G=1.0756, loss_D=1.1995
# Эпоха 7/15 | loss_G=1.0537, loss_D=1.2240
# Эпоха 8/15 | loss_G=0.9980, loss_D=1.2225
# Эпоха 9/15 | loss_G=0.9705, loss_D=1.2426
# Эпоха 10/15 | loss_G=0.9576, loss_D=1.2549

# Эпоха 11/15 | loss_G=0.9163, loss_D=1.2688
# Эпоха 12/15 | loss_G=0.8983, loss_D=1.2768
# Эпоха 13/15 | loss_G=0.8868, loss_D=1.2853
# Эпоха 14/15 | loss_G=0.8726, loss_D=1.2907
# Эпоха 15/15 | loss_G=0.8597, loss_D=1.2949

# %%
# предложенная архитектура, batch_size=64 + BatchNorm в Generator + z_dim = 50 - норм картинки
# Эпоха 1/15 | loss_G=1.1789, loss_D=1.1544

# Эпоха 2/15 | loss_G=1.3124, loss_D=1.1263
# Эпоха 3/15 | loss_G=1.2086, loss_D=1.1804
# Эпоха 4/15 | loss_G=1.1530, loss_D=1.1946
# Эпоха 5/15 | loss_G=1.0137, loss_D=1.2251

# Эпоха 6/15 | loss_G=0.9689, loss_D=1.2669
# Эпоха 7/15 | loss_G=0.9314, loss_D=1.2731
# Эпоха 8/15 | loss_G=0.9123, loss_D=1.2813
# Эпоха 9/15 | loss_G=0.8819, loss_D=1.2972
# Эпоха 10/15 | loss_G=0.8719, loss_D=1.3022

# Эпоха 11/15 | loss_G=0.8553, loss_D=1.3048
# Эпоха 12/15 | loss_G=0.8499, loss_D=1.3107
# Эпоха 13/15 | loss_G=0.8419, loss_D=1.3144
# Эпоха 14/15 | loss_G=0.8303, loss_D=1.3175
# Эпоха 15/15 | loss_G=0.8253, loss_D=1.3207

# %%
# предложенная архитектура, batch_size=64 + BatchNorm в Generator + opt_G и opt_D lr=1e-4 и lr=4e-4
# Эпоха 1/15 | loss_G=1.2186, loss_D=1.0775

# Эпоха 2/15 | loss_G=1.3886, loss_D=1.0166
# Эпоха 3/15 | loss_G=1.3755, loss_D=0.9916
# Эпоха 4/15 | loss_G=1.3040, loss_D=1.0119
# Эпоха 5/15 | loss_G=1.2296, loss_D=1.0404

# Эпоха 6/15 | loss_G=1.2154, loss_D=1.0447
# Эпоха 7/15 | loss_G=1.1986, loss_D=1.0599
# Эпоха 8/15 | loss_G=1.2003, loss_D=1.0633
# Эпоха 9/15 | loss_G=1.2011, loss_D=1.0762
# Эпоха 10/15 | loss_G=1.1962, loss_D=1.0899

# Эпоха 11/15 | loss_G=1.1867, loss_D=1.0944
# Эпоха 12/15 | loss_G=1.1822, loss_D=1.0993
# Эпоха 13/15 | loss_G=1.1761, loss_D=1.1068
# Эпоха 14/15 | loss_G=1.1703, loss_D=1.1140
# Эпоха 15/15 | loss_G=1.1738, loss_D=1.1178

# %%
# # предложенная архитектура, batch_size=64 + BatchNorm в Generator + opt_G и opt_D lr=4e-4 и lr=1e-4

# Эпоха 1/15 | loss_G=0.6807, loss_D=1.3488

# Эпоха 2/15 | loss_G=0.7956, loss_D=1.3275
# Эпоха 3/15 | loss_G=0.8663, loss_D=1.3148
# Эпоха 4/15 | loss_G=0.8634, loss_D=1.3114
# Эпоха 5/15 | loss_G=0.8084, loss_D=1.3365

# Эпоха 6/15 | loss_G=0.7856, loss_D=1.3498
# Эпоха 7/15 | loss_G=0.7745, loss_D=1.3552
# Эпоха 8/15 | loss_G=0.7642, loss_D=1.3614
# Эпоха 9/15 | loss_G=0.7604, loss_D=1.3613
# Эпоха 10/15 | loss_G=0.7583, loss_D=1.3616

# Эпоха 11/15 | loss_G=0.7559, loss_D=1.3629
# Эпоха 12/15 | loss_G=0.7526, loss_D=1.3657
# Эпоха 13/15 | loss_G=0.7486, loss_D=1.3673
# Эпоха 14/15 | loss_G=0.7454, loss_D=1.3679
# Эпоха 15/15 | loss_G=0.7471, loss_D=1.3677
